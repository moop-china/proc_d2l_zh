# %% [markdown]
# # `d2lzh`包索引
#
#
# 函数、类等名称：定义所在章节
#
# * `bbox_to_rect`：[物体检测和边界框](09.03%20目标检测和边界框.ipynb)
# * `Benchmark`：[异步计算](08.2%20异步计算.ipynb)
# * `corr2d`：[二维卷积层](05.01%20二维卷积层.ipynb)
# * `count_tokens`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `data_iter`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `data_iter_consecutive`：[语言模型数据集（周杰伦专辑歌词）](06.03%20语言模型数据集（周杰伦专辑歌词）.ipynb)
# * `data_iter_random`：[语言模型数据集（周杰伦专辑歌词）](06.03%20语言模型数据集（周杰伦专辑歌词）.ipynb)
# * `download_imdb`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `download_voc_pascal`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `evaluate_accuracy`：[图像增广](09.01%20图像增广.ipynb)
# * `get_data_ch7`：[小批量随机梯度下降](07.3%20小批量随机梯度下降.ipynb)
# * `get_fashion_mnist_labels`：[图像分类数据集（Fashion-MNIST）](03.05%20图像分类数据集.ipynb)
# * `get_tokenized_imdb`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `get_vocab_imdb`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `grad_clipping`：[循环神经网络的从零开始实现](06.04%20循环神经网络的从零开始实现.ipynb)
# * `linreg`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `load_data_fashion_mnist`：[深度卷积神经网络（AlexNet）](05.06%20深度卷积神经网络（AlexNet）.ipynb)
# * `load_data_jay_lyrics`：[语言模型数据集（周杰伦专辑歌词）](06.03%20语言模型数据集（周杰伦专辑歌词）.ipynb)
# * `load_data_pikachu`：[物体检测数据集（皮卡丘）](09.06%20目标检测数据集（皮卡丘）.ipynb)
# * `mkdir_if_not_exist`：[实战Kaggle比赛：图像分类（CIFAR-10）](09.12%20实战Kaggle比赛：图像分类（CIFAR-10）.ipynb)
# * `plt`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `predict_rnn`：[循环神经网络的从零开始实现](06.04%20循环神经网络的从零开始实现.ipynb)
# * `predict_rnn_gluon`：[循环神经网络的简洁实现](06.05%20循环神经网络的简洁实现.ipynb)
# * `predict_sentiment`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `preprocess_imdb`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `read_imdb`：[文本情感分类：使用循环神经网络](10.07%20文本情感分类：使用循环神经网络.ipynb)
# * `read_voc_images`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `Residual`：[残差网络（ResNet）](05.11%20残差网络（ResNet）.ipynb)
# * `resnet18`：[多GPU计算的简洁实现](08.5%20多GPU计算的简洁实现.ipynb)
# * `RNNModel`：[循环神经网络的简洁实现](06.05%20循环神经网络的简洁实现.ipynb)
# * `semilogy`：[模型选择、欠拟合和过拟合](03.11%20模型选择、欠拟合和过拟合.ipynb)
# * `set_figsize`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `sgd`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `show_bboxes`：[锚框](09.04%20锚框.ipynb)
# * `show_fashion_mnist`：[图像分类数据集（Fashion-MNIST）](03.05%20图像分类数据集.ipynb)
# * `show_images`：[图像增广](09.01%20图像增广.ipynb)
# * `show_trace_2d`：[梯度下降和随机梯度下降](07.2%20梯度下降和随机梯度下降.ipynb)
# * `squared_loss`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `to_onehot`：[循环神经网络的从零开始实现](06.04%20循环神经网络的从零开始实现.ipynb)
# * `train`：[图像增广](09.01%20图像增广.ipynb)
# * `train_2d`：[梯度下降和随机梯度下降](07.2%20梯度下降和随机梯度下降.ipynb)
# * `train_and_predict_rnn`：[循环神经网络的从零开始实现](06.04%20循环神经网络的从零开始实现.ipynb)
# * `train_and_predict_rnn_gluon `：[循环神经网络的简洁实现](06.05%20循环神经网络的简洁实现.ipynb)
# * `train_ch3`：[softmax回归的从零开始实现](03.06%20softmax回归的从零开始实现.ipynb)
# * `train_ch5`：[卷积神经网络（LeNet）](05.05%20卷积神经网络（LeNet）.ipynb)
# * `train_ch7`：[小批量随机梯度下降](07.3%20小批量随机梯度下降.ipynb)
# * `train_gluon_ch7`：[小批量随机梯度下降](07.3%20小批量随机梯度下降.ipynb)
# * `try_all_gpus`：[图像增广](09.01%20图像增广.ipynb)
# * `try_gpu`：[卷积神经网络（LeNet）](05.05%20卷积神经网络（LeNet）.ipynb)
# * `use_svg_display`：[线性回归的从零开始实现](03.02%20线性回归的从零开始实现.ipynb)
# * `VOC_CLASSES`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `VOC_COLORMAP`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `voc_label_indices`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `voc_rand_crop`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
# * `VOCSegDataset`：[语义分割和数据集](09.09%20语义分割和数据集.ipynb)
